# %% [markdown]
# ### Series is first datatype in pandas and its very similar to numpy arrays
# its build on top of numpy array here we can pass any object as well we can provide the indexing lables

# %%
#Series===list ,array,dictionary
import numpy as np
import pandas as pd
l=[11,22,33,44]
arr=np.array([111,222,333,444])
d={'a':[11,22,45,75],
    'b':[34,56,77,9],
    'c':[11,45,66,5],
   'd':[51,23,5,9]}
label=['a1','b1','c1','d1']

# %%
pd.Series(arr)
# Out:
# 0    111
# 1    222
# 2    333
# 3    444
# dtype: int32

# %%
pd.Series([len,print,2,4])
# Out:
# 0      <built-in function len>
# 1    <built-in function print>
# 2                            2
# 3                            4
# dtype: object

# %%
pd.Series(arr,label)
#pd.Series(d)
# Out:
# a1    111
# b1    222
# c1    333
# d1    444
# dtype: int32

# %%
pd.Series(label)
#pd.Series([len,print,sum])
# Out:
# 0    a1
# 1    b1
# 2    c1
# 3    d1
# dtype: object

# %%
ser1=pd.Series(data=[1,2,3,4],index=['In','Jp','IT','USA'])
print(ser1)
ser2=pd.Series(data=[3,4,56,4],index=['ge','In','USA','It'])
print(ser2)
ser1*ser2
# Out:
# In     1
# Jp     2
# IT     3
# USA    4
# dtype: int64
# ge      3
# In      4
# USA    56
# It      4
# dtype: int64
# IT       NaN
# In       4.0
# It       NaN
# Jp       NaN
# USA    224.0
# ge       NaN
# dtype: float64

# %% [markdown]
# Dataframe

# %%
#creating dataframe by passing list 
df1=pd.DataFrame(d)
df1
# Out:
#     a   b   c   d
# 0  11  34  11  51
# 1  22  56  45  23
# 2  45  77  66   5
# 3  75   9   5   9

# %%
df1
# Out:
#     a   b   c   d
# 0  11  34  11  51
# 1  22  56  45  23
# 2  45  77  66   5
# 3  75   9   5   9

# %%
df = pd.DataFrame(l)
df
# Out:
#     0
# 0  11
# 1  22
# 2  33
# 3  44

# %%
#creating dataframe by passing arr
pd.DataFrame(arr)
# Out:
#      0
# 0  111
# 1  222
# 2  333
# 3  444

# %%
pd.DataFrame(arr,label)
# Out:
#       0
# a1  111
# b1  222
# c1  333
# d1  444

# %%
label
# Out:
# ['a1', 'b1', 'c1', 'd1']

# %%
d
# Out:
# {'a': [11, 22, 45, 75],
#  'b': [34, 56, 77, 9],
#  'c': [11, 45, 66, 5],
#  'd': [51, 23, 5, 9]}

# %%
#creating dataframe by passing dict
pd.DataFrame(data=d,index=label)
# Out:
#      a   b   c   d
# a1  11  34  11  51
# b1  22  56  45  23
# c1  45  77  66   5
# d1  75   9   5   9

# %%
from numpy.random import randn

# %%
df=pd.DataFrame(randn(5,4),['A','B','C','D','E'],['W','X','Y','Z'])

# %%
df
# Out:
#           W         X         Y         Z
# A  0.195661  2.057496 -0.090068  0.501263
# B  0.308278  0.975193  0.787140 -0.945513
# C -1.185900  0.345048 -1.324300  1.294915
# D -2.631051 -0.696055  0.150387 -0.731605
# E -0.840064 -0.662087  0.590785 -1.472446

# %%
print("\nA column is created by assigning it in relation to an existing column\n",'-'*75, sep='')
df['New'] = df['X']+df['Z']
df['New (Sum of X and Z)'] = df['X']+df['Z']
df
# Out:
# A column is created by assigning it in relation to an existing column
# ---------------------------------------------------------------------------
#           W         X         Y         Z       New  New (Sum of X and Z)
# A  0.195661  2.057496 -0.090068  0.501263  2.558759              2.558759
# B  0.308278  0.975193  0.787140 -0.945513  0.029680              0.029680
# C -1.185900  0.345048 -1.324300  1.294915  1.639963              1.639963
# D -2.631051 -0.696055  0.150387 -0.731605 -1.427660             -1.427660
# E -0.840064 -0.662087  0.590785 -1.472446 -2.134533             -2.134533

# %%
df['new']=df['X']+df['Y']
df
# Out:
#           W         X         Y         Z       New  New (Sum of X and Z)  \
# A  0.195661  2.057496 -0.090068  0.501263  2.558759              2.558759
# B  0.308278  0.975193  0.787140 -0.945513  0.029680              0.029680
# C -1.185900  0.345048 -1.324300  1.294915  1.639963              1.639963
# D -2.631051 -0.696055  0.150387 -0.731605 -1.427660             -1.427660
# E -0.840064 -0.662087  0.590785 -1.472446 -2.134533             -2.134533
#
#         new
# A  1.967428
# B  1.762333
# C -0.979252
# D -0.545667
# E -0.071302

# %%
df
# Out:
#           W         X         Y         Z       New  New (Sum of X and Z)  \
# A  0.195661  2.057496 -0.090068  0.501263  2.558759              2.558759
# B  0.308278  0.975193  0.787140 -0.945513  0.029680              0.029680
# C -1.185900  0.345048 -1.324300  1.294915  1.639963              1.639963
# D -2.631051 -0.696055  0.150387 -0.731605 -1.427660             -1.427660
# E -0.840064 -0.662087  0.590785 -1.472446 -2.134533             -2.134533
#
#         new
# A  1.967428
# B  1.762333
# C -0.979252
# D -0.545667
# E -0.071302

# %%
del df['New (Sum of X and Z)']
df
# Out:
#           W         X         Y         Z       New       new
# A  0.195661  2.057496 -0.090068  0.501263  2.558759  1.967428
# B  0.308278  0.975193  0.787140 -0.945513  0.029680  1.762333
# C -1.185900  0.345048 -1.324300  1.294915  1.639963 -0.979252
# D -2.631051 -0.696055  0.150387 -0.731605 -1.427660 -0.545667
# E -0.840064 -0.662087  0.590785 -1.472446 -2.134533 -0.071302

# %%
df['New']
# Out:
# A    2.558759
# B    0.029680
# C    1.639963
# D   -1.427660
# E   -2.134533
# Name: New, dtype: float64

# %%
df[['W','Z','X']]
# Out:
#           W         Z         X
# A  0.195661  0.501263  2.057496
# B  0.308278 -0.945513  0.975193
# C -1.185900  1.294915  0.345048
# D -2.631051 -0.731605 -0.696055
# E -0.840064 -1.472446 -0.662087

# %%
# add a column new which is nothing but addition of W and X into the df

# %%
df[['W','X']]
# Out:
#           W         X
# A  0.195661  2.057496
# B  0.308278  0.975193
# C -1.185900  0.345048
# D -2.631051 -0.696055
# E -0.840064 -0.662087

# %%
df['New']=df['W']+df['X']
df
# Out:
#           W         X         Y         Z       New       new
# A  0.195661  2.057496 -0.090068  0.501263  2.253157  1.967428
# B  0.308278  0.975193  0.787140 -0.945513  1.283471  1.762333
# C -1.185900  0.345048 -1.324300  1.294915 -0.840853 -0.979252
# D -2.631051 -0.696055  0.150387 -0.731605 -3.327106 -0.545667
# E -0.840064 -0.662087  0.590785 -1.472446 -1.502151 -0.071302

# %%
df
# Out:
#           W         X         Y         Z       New       new
# A  0.195661  2.057496 -0.090068  0.501263  2.253157  1.967428
# B  0.308278  0.975193  0.787140 -0.945513  1.283471  1.762333
# C -1.185900  0.345048 -1.324300  1.294915 -0.840853 -0.979252
# D -2.631051 -0.696055  0.150387 -0.731605 -3.327106 -0.545667
# E -0.840064 -0.662087  0.590785 -1.472446 -1.502151 -0.071302

# %%
#axis = 0 for droping the row
#axis = 1 for droping the column
df.drop('New', axis = 1)
# Out:
#           W         X         Y         Z       new
# A  0.195661  2.057496 -0.090068  0.501263  1.967428
# B  0.308278  0.975193  0.787140 -0.945513  1.762333
# C -1.185900  0.345048 -1.324300  1.294915 -0.979252
# D -2.631051 -0.696055  0.150387 -0.731605 -0.545667
# E -0.840064 -0.662087  0.590785 -1.472446 -0.071302

# %%
df
# Out:
#           W         X         Y         Z       New       new
# A  0.195661  2.057496 -0.090068  0.501263  2.253157  1.967428
# B  0.308278  0.975193  0.787140 -0.945513  1.283471  1.762333
# C -1.185900  0.345048 -1.324300  1.294915 -0.840853 -0.979252
# D -2.631051 -0.696055  0.150387 -0.731605 -3.327106 -0.545667
# E -0.840064 -0.662087  0.590785 -1.472446 -1.502151 -0.071302

# %%
df
# Out:
#           W         X         Y         Z       New       new
# A  0.195661  2.057496 -0.090068  0.501263  2.253157  1.967428
# B  0.308278  0.975193  0.787140 -0.945513  1.283471  1.762333
# C -1.185900  0.345048 -1.324300  1.294915 -0.840853 -0.979252
# D -2.631051 -0.696055  0.150387 -0.731605 -3.327106 -0.545667
# E -0.840064 -0.662087  0.590785 -1.472446 -1.502151 -0.071302

# %%
df.drop('Y',axis=1)
# Out:
#           W         X         Z       New       new
# A  0.195661  2.057496  0.501263  2.253157  1.967428
# B  0.308278  0.975193 -0.945513  1.283471  1.762333
# C -1.185900  0.345048  1.294915 -0.840853 -0.979252
# D -2.631051 -0.696055 -0.731605 -3.327106 -0.545667
# E -0.840064 -0.662087 -1.472446 -1.502151 -0.071302

# %%
print("\nLabel-based 'loc' method can be used for selecting row(s)\n",'-'*60, sep='')
print("\nSingle row\n")
print(df.loc['E'])
# Out:
# Label-based 'loc' method can be used for selecting row(s)
# ------------------------------------------------------------
#
# Single row
#
# W     -0.840064
# X     -0.662087
# Y      0.590785
# Z     -1.472446
# New   -1.502151
# new   -0.071302
# Name: E, dtype: float64

# %%
print("\nMultiple rows\n")
print(df.loc[['B','C']])
# Out:
# Multiple rows
#
#           W         X        Y         Z       New       new
# B  0.308278  0.975193  0.78714 -0.945513  1.283471  1.762333
# C -1.185900  0.345048 -1.32430  1.294915 -0.840853 -0.979252

# %%
#selection of rows
df.loc['A']
# Out:
# W      0.195661
# X      2.057496
# Y     -0.090068
# Z      0.501263
# New    2.253157
# new    1.967428
# Name: A, dtype: float64

# %%
df
# Out:
#           W         X         Y         Z       New       new
# A  0.195661  2.057496 -0.090068  0.501263  2.253157  1.967428
# B  0.308278  0.975193  0.787140 -0.945513  1.283471  1.762333
# C -1.185900  0.345048 -1.324300  1.294915 -0.840853 -0.979252
# D -2.631051 -0.696055  0.150387 -0.731605 -3.327106 -0.545667
# E -0.840064 -0.662087  0.590785 -1.472446 -1.502151 -0.071302

# %%
df.loc[['B','C'],['Y','Z']]
# Out:
#          Y         Z
# B  0.78714 -0.945513
# C -1.32430  1.294915

# %%
df
# Out:
#           W         X         Y         Z       New       new
# A  0.195661  2.057496 -0.090068  0.501263  2.253157  1.967428
# B  0.308278  0.975193  0.787140 -0.945513  1.283471  1.762333
# C -1.185900  0.345048 -1.324300  1.294915 -0.840853 -0.979252
# D -2.631051 -0.696055  0.150387 -0.731605 -3.327106 -0.545667
# E -0.840064 -0.662087  0.590785 -1.472446 -1.502151 -0.071302

# %%
print("\nIndex position based 'iloc' method can be used for selecting row(s)\n",'-'*70, sep='')
print("\nSingle row\n")
print(df.iloc[2])
# Out:
# Index position based 'iloc' method can be used for selecting row(s)
# ----------------------------------------------------------------------
#
# Single row
#
# W     -1.185900
# X      0.345048
# Y     -1.324300
# Z      1.294915
# New   -0.840853
# new   -0.979252
# Name: C, dtype: float64

# %%
#selecting loc by passing index
df.iloc[2]
# Out:
# W     -1.185900
# X      0.345048
# Y     -1.324300
# Z      1.294915
# New   -0.840853
# new   -0.979252
# Name: C, dtype: float64

# %%
df.iloc[[2,4]]
# Out:
#           W         X         Y         Z       New       new
# C -1.185900  0.345048 -1.324300  1.294915 -0.840853 -0.979252
# E -0.840064 -0.662087  0.590785 -1.472446 -1.502151 -0.071302

# %%
df
# Out:
#           W         X         Y         Z       New       new
# A  0.195661  2.057496 -0.090068  0.501263  2.253157  1.967428
# B  0.308278  0.975193  0.787140 -0.945513  1.283471  1.762333
# C -1.185900  0.345048 -1.324300  1.294915 -0.840853 -0.979252
# D -2.631051 -0.696055  0.150387 -0.731605 -3.327106 -0.545667
# E -0.840064 -0.662087  0.590785 -1.472446 -1.502151 -0.071302

# %%
print("\nSubset comprising of rows B , C, and D, and columns W and X, is\n")
df.iloc[[1,2,3],[0,1]]
# Out:
# Subset comprising of rows B , C, and D, and columns W and X, is
#           W         X
# B  0.308278  0.975193
# C -1.185900  0.345048
# D -2.631051 -0.696055

# %%
print("\nElement at row 'B' and column 'Y' is\n") 
print(df.loc[['B'],['Y']])
# Out:
# Element at row 'B' and column 'Y' is
#
#          Y
# B  0.78714

# %%
print("\nSubset comprising of rows B and D, and columns W and Y, is\n")
# Out:
# Subset comprising of rows B and D, and columns W and Y, is

# %%
df
# Out:
#           W         X         Y         Z       New       new
# A  0.195661  2.057496 -0.090068  0.501263  2.253157  1.967428
# B  0.308278  0.975193  0.787140 -0.945513  1.283471  1.762333
# C -1.185900  0.345048 -1.324300  1.294915 -0.840853 -0.979252
# D -2.631051 -0.696055  0.150387 -0.731605 -3.327106 -0.545667
# E -0.840064 -0.662087  0.590785 -1.472446 -1.502151 -0.071302

# %%
#condition give such a value of X and Y where W>0
df[df['W']>0]
# Out:
#           W         X         Y         Z       New       new
# A  0.195661  2.057496 -0.090068  0.501263  2.253157  1.967428
# B  0.308278  0.975193  0.787140 -0.945513  1.283471  1.762333

# %%
df
# Out:
#           W         X         Y         Z       New       new
# A  0.195661  2.057496 -0.090068  0.501263  2.253157  1.967428
# B  0.308278  0.975193  0.787140 -0.945513  1.283471  1.762333
# C -1.185900  0.345048 -1.324300  1.294915 -0.840853 -0.979252
# D -2.631051 -0.696055  0.150387 -0.731605 -3.327106 -0.545667
# E -0.840064 -0.662087  0.590785 -1.472446 -1.502151 -0.071302

# %%
#get such a rows where W>0
df[df['W']>0]
# Out:
#           W         X         Y         Z       New       new
# A  0.195661  2.057496 -0.090068  0.501263  2.253157  1.967428
# B  0.308278  0.975193  0.787140 -0.945513  1.283471  1.762333

# %%
df[(df['W']>0) & (df['X']<0)]
# Out:
# Empty DataFrame
# Columns: [W, X, Y, Z, New, new]
# Index: []

# %% [markdown]
# ### Sorting , groupby operations

# %%
df=pd.DataFrame({'Comp':['aaa','bbb','ccc','aaa','ddd','bbb','ccc'],
                'level':['l1','l2','l3','l1','l3','l2','l1'],
                'Sal':[1200009,1240897,2345678,10000,35680,1135,136788]})

# %%
df
# Out:
#   Comp level      Sal
# 0  aaa    l1  1200009
# 1  bbb    l2  1240897
# 2  ccc    l3  2345678
# 3  aaa    l1    10000
# 4  ddd    l3    35680
# 5  bbb    l2     1135
# 6  ccc    l1   136788

# %%
df.sort_values('Sal')
#df['Comp'].apply(len)
# Out:
#   Comp level      Sal
# 5  bbb    l2     1135
# 3  aaa    l1    10000
# 4  ddd    l3    35680
# 6  ccc    l1   136788
# 0  aaa    l1  1200009
# 1  bbb    l2  1240897
# 2  ccc    l3  2345678

# %%
bycomp=df.groupby('Comp')
(list(bycomp))
# Out:
# [('aaa',   Comp level      Sal
#   0  aaa    l1  1200009
#   3  aaa    l1    10000), ('bbb',   Comp level      Sal
#   1  bbb    l2  1240897
#   5  bbb    l2     1135), ('ccc',   Comp level      Sal
#   2  ccc    l3  2345678
#   6  ccc    l1   136788), ('ddd',   Comp level    Sal
#   4  ddd    l3  35680)]

# %%
bycomp.mean()
# Out:
#             Sal
# Comp
# aaa    605004.5
# bbb    621016.0
# ccc   1241233.0
# ddd     35680.0

# %%
bycomp.max()
# Out:
#      level      Sal
# Comp
# aaa     l1  1200009
# bbb     l2  1240897
# ccc     l3  2345678
# ddd     l3    35680

# %% [markdown]
# ### ** Find Null Values or Check for Null Values**

# %%
df=pd.DataFrame({'A':[1,2,3,np.nan],
                'B':[2,4,np.nan,5],
                'C':[1,3,6,8]})

# %%
df
# Out:
#      A    B  C
# 0  1.0  2.0  1
# 1  2.0  4.0  3
# 2  3.0  NaN  6
# 3  NaN  5.0  8

# %%
df.isnull()
# Out:
#        A      B      C
# 0  False  False  False
# 1  False  False  False
# 2  False   True  False
# 3   True  False  False

# %%
df.dropna()
# Out:
#      A    B  C
# 0  1.0  2.0  1
# 1  2.0  4.0  3

# %%
df
# Out:
#      A    B  C
# 0  1.0  2.0  1
# 1  2.0  4.0  3
# 2  3.0  NaN  6
# 3  NaN  5.0  8

# %% [markdown]
# ### ** Filling in NaN values with something else: **

# %%
df
# Out:
#      A    B  C
# 0  1.0  2.0  1
# 1  2.0  4.0  3
# 2  3.0  NaN  6
# 3  NaN  5.0  8

# %%
df.fillna(df.max())
# Out:
#      A    B  C
# 0  1.0  2.0  1
# 1  2.0  4.0  3
# 2  3.0  5.0  6
# 3  3.0  5.0  8

# %%
df.fillna(df.sum())
# Out:
#      A     B  C
# 0  1.0   2.0  1
# 1  2.0   4.0  3
# 2  3.0  11.0  6
# 3  6.0   5.0  8

# %%
df.fillna(df.min())
# Out:
#      A    B  C
# 0  1.0  2.0  1
# 1  2.0  4.0  3
# 2  3.0  2.0  6
# 3  1.0  5.0  8

# %%
df.fillna(df.median())
# Out:
#      A    B  C
# 0  1.0  2.0  1
# 1  2.0  4.0  3
# 2  3.0  4.0  6
# 3  2.0  5.0  8

# %%
df['A'].fillna(df['A'].mean())
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    2.0
# Name: A, dtype: float64

# %%
#fill the missing values by sum, max,min, median
df=pd.DataFrame({'col1':[1,2,np.nan,3,np.nan],'col2':[11,33,45,np.nan,np.nan],'col3':[45,np.nan,89,22,45]})

# %%
df.fillna(df.sum())
# Out:
#    col1  col2   col3
# 0   1.0  11.0   45.0
# 1   2.0  33.0  201.0
# 2   6.0  45.0   89.0
# 3   3.0  89.0   22.0
# 4   6.0  89.0   45.0

# %%
#applying functions 
def triple(x):
    return x*3

# %%
df1=pd.DataFrame({'a':[1,2,3],
                 'b':[2,4,3],
                 'c':[1,5,2]})

# %%
df1
# Out:
#    a  b  c
# 0  1  2  1
# 1  2  4  5
# 2  3  3  2

# %%
df1.apply(triple)
# Out:
#    a   b   c
# 0  3   6   3
# 1  6  12  15
# 2  9   9   6

# %%
df1.columns
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df=pd.DataFrame({'Month':['Jan','Feb','Mar','April','May','Jun','July','Aug','Sept','Oct','Nov','Dec'],
                'Birth':[100,232,563,898,333,777,987,224,890,124,567,890]})


#add new column name len which shows lenth of month in above df

# %%
df['len']=df['Month'].apply(len)
df
# Out:
#     Month  Birth  len
# 0     Jan    100    3
# 1     Feb    232    3
# 2     Mar    563    3
# 3   April    898    5
# 4     May    333    3
# 5     Jun    777    3
# 6    July    987    4
# 7     Aug    224    3
# 8    Sept    890    4
# 9     Oct    124    3
# 10    Nov    567    3
# 11    Dec    890    3

# %%
df.to_csv('month_birth.csv',index=False)

# %%
pd.read_csv('month_birth.csv')
# Out:
#     Month  Birth  len
# 0     Jan    100    3
# 1     Feb    232    3
# 2     Mar    563    3
# 3   April    898    5
# 4     May    333    3
# 5     Jun    777    3
# 6    July    987    4
# 7     Aug    224    3
# 8    Sept    890    4
# 9     Oct    124    3
# 10    Nov    567    3
# 11    Dec    890    3

# %% [raw]
# # concataneting

# %%
df1=pd.DataFrame({'A':['A0','A1','A2'],
                  'B':['B0','B1','B2'],
                  'C':['C0','C1','C2']},index=[0,1,2])
df2=pd.DataFrame({'A':['A3','A4','A5'],
                 'B':['B3','B4','B5'],
                 'C':['C3','C4','C5']},index=[3,4,5])

# %%
df1
# Out:
#     A   B   C
# 0  A0  B0  C0
# 1  A1  B1  C1
# 2  A2  B2  C2

# %%
df2
# Out:
#     A   B   C
# 3  A3  B3  C3
# 4  A4  B4  C4
# 5  A5  B5  C5

# %%
df3=pd.concat([df1,df2], axis = 0) ##by default axis=0

# %%
df3
# Out:
#     A   B   C
# 0  A0  B0  C0
# 1  A1  B1  C1
# 2  A2  B2  C2
# 3  A3  B3  C3
# 4  A4  B4  C4
# 5  A5  B5  C5

# %%
dff=pd.concat([df1,df2],axis=1)

# %%
dff
# Out:
#      A    B    C    A    B    C
# 0   A0   B0   C0  NaN  NaN  NaN
# 1   A1   B1   C1  NaN  NaN  NaN
# 2   A2   B2   C2  NaN  NaN  NaN
# 3  NaN  NaN  NaN   A3   B3   C3
# 4  NaN  NaN  NaN   A4   B4   C4
# 5  NaN  NaN  NaN   A5   B5   C5

# %%
dff.fillna(value=5,inplace=True)
dff
# Out:
#     A   B   C   A   B   C
# 0  A0  B0  C0   5   5   5
# 1  A1  B1  C1   5   5   5
# 2  A2  B2  C2   5   5   5
# 3   5   5   5  A3  B3  C3
# 4   5   5   5  A4  B4  C4
# 5   5   5   5  A5  B5  C5

# %%
import pandas as pd
df=pd.DataFrame({'c1':[1,2,3,4,2,4,5],'c2':[11,22,33,33,44,44,55],'c3':[111,333,333,333,444,444,333],'c4':['aaa','bb','bb','ccc','ddd','ddd','ddd']})

# %%
df
# Out:
#    c1  c2   c3   c4
# 0   1  11  111  aaa
# 1   2  22  333   bb
# 2   3  33  333   bb
# 3   4  33  333  ccc
# 4   2  44  444  ddd
# 5   4  44  444  ddd
# 6   5  55  333  ddd

# %% [markdown]
# # Info on unique value

# %%
df.nunique()
# Out:
# c1    5
# c2    5
# c3    3
# c4    4
# dtype: int64

# %%
df['c3'].unique()
# Out:
# array([111, 333, 444], dtype=int64)

# %%
df['c4'].value_counts()
# Out:
# ddd    3
# bb     2
# aaa    1
# ccc    1
# Name: c4, dtype: int64

# %%
df['c1'].unique()
# Out:
# array([1, 2, 3, 4, 5], dtype=int64)

# %%
df['c1'].nunique()
# Out:
# 5

# %%
df['c1'].value_counts()
# Out:
# 4    2
# 2    2
# 5    1
# 3    1
# 1    1
# Name: c1, dtype: int64

# %% [raw]
# # Selecting Data

# %%
df
# Out:
#    c1  c2   c3   c4
# 0   1  11  111  aaa
# 1   2  22  333   bb
# 2   3  33  333   bb
# 3   4  33  333  ccc
# 4   2  44  444  ddd
# 5   4  44  444  ddd
# 6   5  55  333  ddd

# %%
df[df['c4']=='ddd']
# Out:
#    c1  c2   c3   c4
# 4   2  44  444  ddd
# 5   4  44  444  ddd
# 6   5  55  333  ddd

# %%
df[df['c4']=='ddd']
# Out:
#    c1  c2   c3   c4
# 4   2  44  444  ddd
# 5   4  44  444  ddd
# 6   5  55  333  ddd

# %%
newdf=df[(df['c2']==44)&(df['c3']==444)]

# %%
import numpy as np
import pandas as pd
import os

# %%
titanic_train = pd.read_csv("https://raw.githubusercontent.com/sushma-projects/ML-Projects/master/titanic.csv",sep='\t')   
titanic_train.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
titanic_train.tail()
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 151          152         1       1  Pears, Mrs. Thomas (Edith Wearne)  female
# 152          153         0       3                   Meo, Mr. Alfonzo    male
# 153          154         0       3    van Billiard, Mr. Austin Blyler    male
# 154          155         0       3              Olsen, Mr. Ole Martin    male
# 155          156         0       1        Williams, Mr. Charles Duane    male
#
#       Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 151  22.0      1      0      113776  66.6000    C2        S
# 152  55.5      0      0  A.5. 11206   8.0500   NaN        S
# 153  40.5      0      2    A/5. 851  14.5000   NaN        S
# 154   NaN      0      0   Fa 265302   7.3125   NaN        S
# 155  51.0      0      1    PC 17597  61.3792   NaN        C

# %%
titanic_train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic_train.dtypes == "object"
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
a = titanic_train.dtypes[titanic_train.dtypes == "object"].index

# %%
a
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
titanic_train[a]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 151                  Pears, Mrs. Thomas (Edith Wearne)  female
# 152                                   Meo, Mr. Alfonzo    male
# 153                    van Billiard, Mr. Austin Blyler    male
# 154                              Olsen, Mr. Ole Martin    male
# 155                        Williams, Mr. Charles Duane    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
titanic_train[a].describe()
# Out:
#                                Name   Sex  Ticket Cabin Embarked
# count                           156   156     156    31      155
# unique                          156     2     145    28        3
# top     Nicola-Yarred, Miss. Jamila  male  237736   D26        S
# freq                              1   100       2     2      110

# %%
titanic_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   156.000000  156.000000  156.000000  126.000000  156.000000
# mean     78.500000    0.346154    2.423077   28.141508    0.615385
# std      45.177428    0.477275    0.795459   14.613880    1.056235
# min       1.000000    0.000000    1.000000    0.830000    0.000000
# 25%      39.750000    0.000000    2.000000   19.000000    0.000000
# 50%      78.500000    0.000000    3.000000   26.000000    0.000000
# 75%     117.250000    1.000000    3.000000   35.000000    1.000000
# max     156.000000    1.000000    3.000000   71.000000    5.000000
#
#             Parch        Fare
# count  156.000000  156.000000
# mean     0.397436   28.109587
# std      0.870146   39.401047
# min      0.000000    6.750000
# 25%      0.000000    8.003150
# 50%      0.000000   14.454200
# 75%      0.000000   30.371850
# max      5.000000  263.000000

# %%
titanic_train[['Name','Sex','Age']]
# Out:
#                                                   Name     Sex   Age
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# 151                  Pears, Mrs. Thomas (Edith Wearne)  female  22.0
# 152                                   Meo, Mr. Alfonzo    male  55.5
# 153                    van Billiard, Mr. Austin Blyler    male  40.5
# 154                              Olsen, Mr. Ole Martin    male   NaN
# 155                        Williams, Mr. Charles Duane    male  51.0
#
# [156 rows x 3 columns]

# %%
sorted(titanic_train["Name"])
# Out:
# ['Ahlin, Mrs. Johan (Johanna Persdotter Larsson)',
#  'Allen, Mr. William Henry',
#  'Andersson, Miss. Ellis Anna Maria',
#  'Andersson, Miss. Erna Alexandra',
#  'Andersson, Mr. Anders Johan',
#  'Andersson, Mr. August Edvard ("Wennerstrom")',
#  'Andreasson, Mr. Paul Edvin',
#  'Andrew, Mr. Edgardo Samuel',
#  'Arnold-Franchi, Mrs. Josef (Josefine Franchi)',
#  'Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)',
#  'Attalah, Miss. Malake',
#  'Backstrom, Mrs. Karl Alfred (Maria Mathilda Gustafsson)',
#  'Barton, Mr. David John',
#  'Bateman, Rev. Robert James',
#  'Baxter, Mr. Quigg Edmond',
#  'Beesley, Mr. Lawrence',
#  'Bing, Mr. Lee',
#  'Bonnell, Miss. Elizabeth',
#  'Boulos, Mrs. Joseph (Sultana)',
#  'Braund, Mr. Owen Harris',
#  'Burke, Mr. Jeremiah',
#  'Byles, Rev. Thomas Roussel Davids',
#  'Caldwell, Master. Alden Gates',
#  'Cann, Mr. Ernest Charles',
#  'Carrau, Mr. Francisco M',
#  'Celotti, Mr. Francesco',
#  'Chaffee, Mr. Herbert Fuller',
# ...

# %%
sorted(titanic_train["Name"])
# Out:
# ['Ahlin, Mrs. Johan (Johanna Persdotter Larsson)',
#  'Allen, Mr. William Henry',
#  'Andersson, Miss. Ellis Anna Maria',
#  'Andersson, Miss. Erna Alexandra',
#  'Andersson, Mr. Anders Johan',
#  'Andersson, Mr. August Edvard ("Wennerstrom")',
#  'Andreasson, Mr. Paul Edvin',
#  'Andrew, Mr. Edgardo Samuel',
#  'Arnold-Franchi, Mrs. Josef (Josefine Franchi)',
#  'Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)',
#  'Attalah, Miss. Malake',
#  'Backstrom, Mrs. Karl Alfred (Maria Mathilda Gustafsson)',
#  'Barton, Mr. David John',
#  'Bateman, Rev. Robert James',
#  'Baxter, Mr. Quigg Edmond',
#  'Beesley, Mr. Lawrence',
#  'Bing, Mr. Lee',
#  'Bonnell, Miss. Elizabeth',
#  'Boulos, Mrs. Joseph (Sultana)',
#  'Braund, Mr. Owen Harris',
#  'Burke, Mr. Jeremiah',
#  'Byles, Rev. Thomas Roussel Davids',
#  'Caldwell, Master. Alden Gates',
#  'Cann, Mr. Ernest Charles',
#  'Carrau, Mr. Francisco M',
#  'Celotti, Mr. Francesco',
#  'Chaffee, Mr. Herbert Fuller',
# ...

# %%
sorted(titanic_train["Name"])[:10]
# Out:
# ['Ahlin, Mrs. Johan (Johanna Persdotter Larsson)',
#  'Allen, Mr. William Henry',
#  'Andersson, Miss. Ellis Anna Maria',
#  'Andersson, Miss. Erna Alexandra',
#  'Andersson, Mr. Anders Johan',
#  'Andersson, Mr. August Edvard ("Wennerstrom")',
#  'Andreasson, Mr. Paul Edvin',
#  'Andrew, Mr. Edgardo Samuel',
#  'Arnold-Franchi, Mrs. Josef (Josefine Franchi)',
#  'Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)']

# %%
titanic_train["Name"].describe()
# Out:
# count                             156
# unique                            156
# top       Nicola-Yarred, Miss. Jamila
# freq                                1
# Name: Name, dtype: object

# %%
titanic_train[["Ticket"]]
# Out:
#                Ticket
# 0           A/5 21171
# 1            PC 17599
# 2    STON/O2. 3101282
# 3              113803
# 4              373450
# ..                ...
# 151            113776
# 152        A.5. 11206
# 153          A/5. 851
# 154         Fa 265302
# 155          PC 17597
#
# [156 rows x 1 columns]

# %%
titanic_train[["Ticket"]][4:9]
# Out:
#    Ticket
# 4  373450
# 5  330877
# 6   17463
# 7  349909
# 8  347742

# %%
titanic_train["Ticket"].describe()
# Out:
# count        156
# unique       145
# top       237736
# freq           2
# Name: Ticket, dtype: object

# %%
titanic_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic_train["Cabin"][0:15]       # Check the first 15 tickets
# Out:
# 0      NaN
# 1      C85
# 2      NaN
# 3     C123
# 4      NaN
# 5      NaN
# 6      E46
# 7      NaN
# 8      NaN
# 9      NaN
# 10      G6
# 11    C103
# 12     NaN
# 13     NaN
# 14     NaN
# Name: Cabin, dtype: object

# %%
titanic_train["Cabin"].unique()   # Check unique cabins
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2'], dtype=object)

# %%
titanic_train["Pclass"]
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 151    1
# 152    3
# 153    3
# 154    3
# 155    1
# Name: Pclass, Length: 156, dtype: int64

# %%
titanic_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   156.000000  156.000000  156.000000  126.000000  156.000000
# mean     78.500000    0.346154    2.423077   28.141508    0.615385
# std      45.177428    0.477275    0.795459   14.613880    1.056235
# min       1.000000    0.000000    1.000000    0.830000    0.000000
# 25%      39.750000    0.000000    2.000000   19.000000    0.000000
# 50%      78.500000    0.000000    3.000000   26.000000    0.000000
# 75%     117.250000    1.000000    3.000000   35.000000    1.000000
# max     156.000000    1.000000    3.000000   71.000000    5.000000
#
#             Parch        Fare
# count  156.000000  156.000000
# mean     0.397436   28.109587
# std      0.870146   39.401047
# min      0.000000    6.750000
# 25%      0.000000    8.003150
# 50%      0.000000   14.454200
# 75%      0.000000   30.371850
# max      5.000000  263.000000

# %%
#show how many null values
print(titanic_train.isnull().sum().sum())
# Out:
# 156

# %%
# to remove the null values we can use fillna method
titanic_train.Cabin = titanic_train.Cabin.fillna("unknown")

# %%
print(titanic_train.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             30
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          125
# Embarked         1
# dtype: int64

# %%
titanic_train.shape
# Out:
# (156, 12)

# %%
titanic_train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  156 non-null    int64
#  1   Survived     156 non-null    int64
#  2   Pclass       156 non-null    int64
#  3   Name         156 non-null    object
#  4   Sex          156 non-null    object
#  5   Age          126 non-null    float64
#  6   SibSp        156 non-null    int64
#  7   Parch        156 non-null    int64
#  8   Ticket       156 non-null    object
#  9   Fare         156 non-null    float64
#  10  Cabin        156 non-null    object
#  11  Embarked     155 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 14.8+ KB

# %%
titanic_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#how to change case to upper
titanic_train.columns.str.upper()
# Out:
# Index(['PASSENGERID', 'SURVIVED', 'PCLASS', 'NAME', 'SEX', 'AGE', 'SIBSP',
#        'PARCH', 'TICKET', 'FARE', 'CABIN', 'EMBARKED'],
#       dtype='object')

# %%
# rename column
titanic_train.rename(columns = {'Fare':'Price'})
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Missing data
titanic_train.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 151        False     False   False  False  False  False  False  False   False
# 152        False     False   False  False  False  False  False  False   False
# 153        False     False   False  False  False  False  False  False   False
# 154        False     False   False  False  False   True  False  False   False
# 155        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
#see is there missing value present in all df
titanic_train.isnull().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
#how many missing value present
titanic_train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             30
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          125
# Embarked         1
# dtype: int64

# %%
#total number of missing value check
titanic_train.isnull().sum().sum()
# Out:
# 156

# %%
#adding a default value for filling na
df_with_0 = titanic_train.fillna(0)

# %%
df_with_0
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_with_0.isnull().sum().sum()
# Out:
# 0

# %%
#fill it with mean
titanic_train['Age'].mean()
# Out:
# 28.141507936507935

# %%
df_with_mean = titanic_train.Age.fillna(titanic_train['Age'].mean())

# %%
df_with_mean
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 151    22.000000
# 152    55.500000
# 153    40.500000
# 154    28.141508
# 155    51.000000
# Name: Age, Length: 156, dtype: float64

# %%
#Droping NA
titanic_train.isnull().sum().sum()
titanic_train.columns
# Out:
# 156

# %%
df_drop =  titanic_train.dropna()

# %%
df_drop.shape
# Out:
# (27, 12)

# %%
df_drop
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# 21            22         1       2
# 23            24         1       1
# 27            28         0       1
# 52            53         1       1
# 54            55         0       1
# 62            63         0       1
# 66            67         1       2
# 75            76         0       3
# 88            89         1       1
# 92            93         0       1
# 96            97         0       1
# 97            98         1       1
# 102          103         0       1
# 110          111         0       1
# 118          119         0       1
# 123          124         1       2
# 124          125         0       1
# 136          137         1       1
# 137          138         0       1
# 139          140         0       1
# ...

# %%
df_with_condition = titanic_train.dropna(thresh = 3)

# %%
df_with_condition.shape
# Out:
# (156, 12)

# %% [markdown]
# # Salary Excercise

# %%
sal=pd.read_csv('Salaries.csv')
sal.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %% [markdown]
# ** Check the head of the DataFrame. **

# %%
sal.head(10)
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# ...

# %% [markdown]
# ** Use the .info() method to find out how many entries there are.**

# %%
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %% [markdown]
# What is the average BasePay ?

# %%
sal['BasePay'].mean()
# Out:
# 66325.44884050643

# %% [markdown]
# ** What is the highest amount of OvertimePay in the dataset ? **

# %%
sal['OvertimePay'].max()
# Out:
# 245131.88

# %% [markdown]
# ** What is the job title of  JOSEPH DRISCOLL ?

# %%
sal[sal['EmployeeName']=='JOSEPH DRISCOLL']['TotalPayBenefits']
# Out:
# 24    270324.91
# Name: TotalPayBenefits, dtype: float64

# %% [markdown]
# ** How much does JOSEPH DRISCOLL make (including benefits)? **

# %%
sal[sal['EmployeeName']=='JOSEPH DRISCOLL']['TotalPayBenefits']
# Out:
# 24    270324.91
# Name: TotalPayBenefits, dtype: float64

# %% [markdown]
# ** What was the average (mean) BasePay of all employees per year? (2011-2014) ? ** grpby(year)

# %%
sal.groupby(['Year']).mean().BasePay
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %% [markdown]
# ** How many unique job titles are there? **

# %% [markdown]
# ** What are the top 5 most common jobs? ** value_counts()
