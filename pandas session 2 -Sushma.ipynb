# %% [markdown]
# # file Read Write operation

# %% [markdown]
# This notebook is the reference code for getting input and output, pandas can read a variety of file types using its pd.read_ methods. Let's take a look at the most common data types:

# %%
import numpy as np
import pandas as pd

# %%
df=pd.DataFrame({'name':['mayu','vish','nish','pratima','utkranti','vinayak','Avishkar'],
                'level':['l1','l2','l3','l5','l1','l2', 'l1'],
                 'Sal':[1234,12324,4574,56780,578957,567, 356]})
df.to_excel('employee.xlsx',sheet_name='Sheet1')

# %%
import numpy as np
import pandas as pd
df=pd.DataFrame({'name':['mayu','vish','nish','pratima','utkranti','vinayak'],
                'level':['l1','l2','l3','l5','l1','l2'],
                 'Sal':[1234,12324,4574,56780,578957,567]})
df.to_csv('employee.csv')

# %%
df=pd.DataFrame({'name':['mayu','vish','nish','pratima','utkranti','vinayak'],
                'level':['l1','l2','l3','l5','l1','l2'],
                 'Sal':[1234,12324,4574,56780,578957,567]})
df.to_csv('employee1.csv', index = False)

# %% [markdown]
# ## CSV
#
# ### CSV Input

# %%
df = pd.read_csv('employee1.csv')
df
# Out:
#        name level     Sal
# 0      mayu    l1    1234
# 1      vish    l2   12324
# 2      nish    l3    4574
# 3   pratima    l5   56780
# 4  utkranti    l1  578957
# 5   vinayak    l2     567

# %% [markdown]
# ### CSV Output

# %%
df.to_csv('example',index=False)

# %%
df
# Out:
#        name level     Sal
# 0      mayu    l1    1234
# 1      vish    l2   12324
# 2      nish    l3    4574
# 3   pratima    l5   56780
# 4  utkranti    l1  578957
# 5   vinayak    l2     567

# %% [markdown]
# ## Excel
# Pandas can read and write excel files, keep in mind, this only imports data. Not formulas or images, having images or macros may cause this read_excel method to crash.

# %%
df = pd.read_excel('employee.xlsx')
df
# Out:
#    Unnamed: 0      name level     Sal
# 0           0      mayu    l1    1234
# 1           1      vish    l2   12324
# 2           2      nish    l3    4574
# 3           3   pratima    l5   56780
# 4           4  utkranti    l1  578957
# 5           5   vinayak    l2     567
# 6           6  Avishkar    l1     356

# %%
df.to_excel('Excel_Sample.xlsx',sheet_name='Sheet1')

# %% [markdown]
# ## HTML
#
# You may need to install htmllib5,lxml, and BeautifulSoup4. In your terminal/command prompt run:
#
#     conda install lxml
#     conda install html5lib
#     conda install BeautifulSoup4
#
# Then restart Jupyter Notebook.
# (or use pip install if you aren't using the Anaconda Distribution)
#
# Pandas can read table tabs off of html. For example:

# %% [markdown]
# ### HTML Input
#
# Pandas read_html function will read tables off of a webpage and return a list of DataFrame objects:

# %%
df = pd.read_html('http://www.fdic.gov/bank/individual/failed/banklist.html')

# %%
df1 = df[0]
df1
# Out:
#                              Bank Name           City  ST   CERT  \
# 0                 The First State Bank  Barboursville  WV  14361
# 1                   Ericson State Bank        Ericson  NE  18265
# 2     City National Bank of New Jersey         Newark  NJ  21111
# 3                        Resolute Bank         Maumee  OH  58317
# 4                Louisa Community Bank         Louisa  KY  58112
# ..                                 ...            ...  ..    ...
# 556                 Superior Bank, FSB       Hinsdale  IL  32646
# 557                Malta National Bank          Malta  OH   6629
# 558    First Alliance Bank & Trust Co.     Manchester  NH  34264
# 559  National State Bank of Metropolis     Metropolis  IL   3815
# 560                   Bank of Honolulu       Honolulu  HI  21029
#
#                    Acquiring Institution       Closing Date
# 0                         MVB Bank, Inc.      April 3, 2020
# 1             Farmers and Merchants Bank  February 14, 2020
# ...

# %%
df1 = df[0]

# %%
# acess the Closing Date column and convert it into the timestamp


close_timestamps = pd.to_datetime(df1['Closing Date'])
#close_timestamps.dt.year.value_counts()

# %%
close_timestamps
# Out:
# 0     2020-04-03
# 1     2020-02-14
# 2     2019-11-01
# 3     2019-10-25
# 4     2019-10-25
#          ...
# 556   2001-07-27
# 557   2001-05-03
# 558   2001-02-02
# 559   2000-12-14
# 560   2000-10-13
# Name: Closing Date, Length: 561, dtype: datetime64[ns]

# %%
close_timestamps.dt.year
# Out:
# 0      2020
# 1      2020
# 2      2019
# 3      2019
# 4      2019
#        ...
# 556    2001
# 557    2001
# 558    2001
# 559    2000
# 560    2000
# Name: Closing Date, Length: 561, dtype: int64

# %%
close_timestamps.dt.year.value_counts()
# Out:
# 2010    157
# 2009    140
# 2011     92
# 2012     51
# 2008     25
# 2013     24
# 2014     18
# 2002     11
# 2017      8
# 2015      8
# 2016      5
# 2001      4
# 2019      4
# 2004      4
# 2007      3
# 2003      3
# 2020      2
# 2000      2
# Name: Closing Date, dtype: int64

# %%
#now you find out for how many months

# %%
df = pd.read_html('https://www.health.ny.gov/vital_records/genealogy.htm')

# %%
df1 = df[0]
df1
# Out:
#   Period Searched      Fee
# 0    1 to 3 years   $22.00
# 1   4 to 10 years   $42.00
# 2  11 to 20 years   $62.00
# 3  21 to 30 years   $82.00
# 4  31 to 40 years  $102.00
# 5  41 to 50 years  $122.00
# 6  51 to 60 years  $142.00
# 7  61 to 70 years  $162.00
# 8  71 to 80 years  $182.00
# 9  81 to 90 years  $202.00

# %%
#aceess the rows where fee is equal to $122.00
df1[df1['Fee'] == '$122.00']
# Out:
#   Period Searched      Fee
# 5  41 to 50 years  $122.00

# %% [markdown]
# JSON Data

# %%
data = pd.read_json('example.json')

# %%
data
# Out:
#    a  b  c  d
# 0  1  2  3  5
# 1  4  5  6  7
# 2  7  8  9  3

# %%
print(data.to_json())
# Out:
# {"a":{"0":1,"1":4,"2":7},"b":{"0":2,"1":5,"2":8},"c":{"0":3,"1":6,"2":9}}

# %%
data = pd.read_json('example.json')

# %%
data
# Out:
#    a  b  c  d
# 0  1  2  3  5
# 1  4  5  6  7
# 2  7  8  9  3

# %%
print(data.to_json())
# Out:
# {"a":{"0":1,"1":4,"2":7},"b":{"0":2,"1":5,"2":8},"c":{"0":3,"1":6,"2":9},"d":{"0":5,"1":7,"2":3}}

# %%
print(data.to_json(orient='records'))
# Out:
# [{"a":1,"b":2,"c":3,"d":5},{"a":4,"b":5,"c":6,"d":7},{"a":7,"b":8,"c":9,"d":3}]

# %% [markdown]
# # Applying all pandas concepts

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'

# %%
# read the above file

# %%
df = pd.read_table(url)

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
#print first 5 and last 7 records
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df.tail(7)
# Out:
#       order_id  quantity            item_name  \
# 4615      1832         1   Chicken Soft Tacos
# 4616      1832         1  Chips and Guacamole
# 4617      1833         1        Steak Burrito
# 4618      1833         1        Steak Burrito
# 4619      1834         1   Chicken Salad Bowl
# 4620      1834         1   Chicken Salad Bowl
# 4621      1834         1   Chicken Salad Bowl
#
#                                      choice_description item_price
# 4615   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]     $8.75
# 4616                                                NaN     $4.45
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75

# %%
#print total records and type of variables
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
#print the dataset columns and how is the dataset indexed?

# %%
#which was the most order item and how many items were ordered?

# %%
c = df.groupby('item_name').sum()

# %%
c
# Out:
#                                        order_id  quantity
# item_name
# 6 Pack Soft Drink                         52322        55
# Barbacoa Bowl                             53972        66
# Barbacoa Burrito                          74718        91
# Barbacoa Crispy Tacos                      5613        12
# Barbacoa Salad Bowl                        9708        10
# Barbacoa Soft Tacos                       18725        25
# Bottled Water                            175944       211
# Bowl                                        472         4
# Burrito                                    1550         6
# Canned Soda                               76396       126
# Canned Soft Drink                        304753       351
# Carnitas Bowl                             62742        71
# Carnitas Burrito                          51652        60
# Carnitas Crispy Tacos                      5868         8
# Carnitas Salad                             1500         1
# ...

# %%
c = c.sort_values(['quantity'])
c
# Out:
#                                        order_id  quantity
# item_name
# Carnitas Salad                             1500         1
# Veggie Crispy Tacos                         668         1
# Chips and Mild Fresh Tomato Salsa           279         1
# Crispy Tacos                                434         2
# Salad                                      1150         2
# Bowl                                        472         4
# Steak Salad                                2362         4
# Veggie Salad                               7265         6
# Carnitas Salad Bowl                        6693         6
# Burrito                                    1550         6
# Carnitas Crispy Tacos                      5868         8
# Veggie Soft Tacos                          5520         8
# Chicken Salad                             10465         9
# Barbacoa Salad Bowl                        9708        10
# Barbacoa Crispy Tacos                      5613        12
# ...

# %%
c.tail(1)
# Out:
#               order_id  quantity
# item_name
# Chicken Bowl    713926       761

# %%
#what was the most ordered item in the choice_description column?

# %%
df.groupby("choice_description").sum().max()
# Out:
# order_id    123455
# quantity       159
# dtype: int64

# %%
c = df.groupby('choice_description').sum()

c =c.sort_values("quantity")
print(c.tail(1))
# Out:
#                     order_id  quantity
# choice_description
# [Diet Coke]           123455       159

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
# turn the item price into float

# %%
dollor = lambda x : float(x[1:])

# %%
df['item_price'] = df.item_price.apply(dollor)

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
#how much was the revenue in the dataset?

# %%
revenue = (df['quantity']* df['item_price']).sum()

# %%
revenue
# Out:
# 39237.02

# %%
#print the df with two columns item name and item price

# %%
df_new = df[['item_name','item_price']]

# %%
df_new
# Out:
#                                   item_name  item_price
# 0              Chips and Fresh Tomato Salsa        2.39
# 1                                      Izze        3.39
# 2                          Nantucket Nectar        3.39
# 3     Chips and Tomatillo-Green Chili Salsa        2.39
# 4                              Chicken Bowl       16.98
# ...                                     ...         ...
# 4617                          Steak Burrito       11.75
# 4618                          Steak Burrito       11.75
# 4619                     Chicken Salad Bowl       11.25
# 4620                     Chicken Salad Bowl        8.75
# 4621                     Chicken Salad Bowl        8.75
#
# [4622 rows x 2 columns]

# %%
#delete the duplicates in the item name and quantity

# %%
filtered = df.drop_duplicates(['item_name','quantity'])

# %%
filtered
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 3890      1559         2                  Carnitas Crispy Tacos
# 3973      1592         4                      Canned Soft Drink
# 4152      1660        10                          Bottled Water
# 4354      1738         2                       Steak Soft Tacos
# 4489      1786         4                    Chips and Guacamole
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
#select only those products with quantity equals to 1

# %%
one_prod = filtered[filtered.quantity == 1]

# %%
one_prod
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 5            3         1                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 10           5         1                    Chips and Guacamole
# 11           6         1                   Chicken Crispy Tacos
# 12           6         1                     Chicken Soft Tacos
# 16           8         1                        Chicken Burrito
# 21          11         1                       Barbacoa Burrito
# 27          14         1                       Carnitas Burrito
# ...

# %%
#select item name and item price columns

# %%
price_per_item = one_prod[['item_name','item_price']]

# %%
price_per_item
# Out:
#                                   item_name  item_price
# 0              Chips and Fresh Tomato Salsa        2.39
# 1                                      Izze        3.39
# 2                          Nantucket Nectar        3.39
# 3     Chips and Tomatillo-Green Chili Salsa        2.39
# 5                              Chicken Bowl       10.98
# 6                             Side of Chips        1.69
# 7                             Steak Burrito       11.75
# 8                          Steak Soft Tacos        9.25
# 10                      Chips and Guacamole        4.45
# 11                     Chicken Crispy Tacos        8.75
# 12                       Chicken Soft Tacos        8.75
# 16                          Chicken Burrito        8.49
# 21                         Barbacoa Burrito        8.99
# 27                         Carnitas Burrito        8.99
# 28                              Canned Soda        1.09
# 33                            Carnitas Bowl        8.99
# ...

# %%
#sort the values from most to less expensive

# %%
price_per_item.sort_values(by = 'item_price',ascending = False)
# Out:
#                                   item_name  item_price
# 606                        Steak Salad Bowl       11.89
# 1229                    Barbacoa Salad Bowl       11.89
# 1132                    Carnitas Salad Bowl       11.89
# 7                             Steak Burrito       11.75
# 168                   Barbacoa Crispy Tacos       11.75
# 39                            Barbacoa Bowl       11.75
# 738                       Veggie Soft Tacos       11.25
# 186                       Veggie Salad Bowl       11.25
# 62                              Veggie Bowl       11.25
# 57                           Veggie Burrito       11.25
# 250                           Chicken Salad       10.98
# 5                              Chicken Bowl       10.98
# 8                          Steak Soft Tacos        9.25
# 554                   Carnitas Crispy Tacos        9.25
# 237                     Carnitas Soft Tacos        9.25
# 56                      Barbacoa Soft Tacos        9.25
# ...

# %%
#what was the quantity of most expensive item?
df.sort_values(by = 'item_price',ascending = False).head(1)
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#       item_price
# 3598       44.25

# %%
#how many times were veggie salad bowl were ordered?

# %%
df[df.item_name == 'Veggie Salad Bowl'].count()
# Out:
# order_id              18
# quantity              18
# item_name             18
# choice_description    18
# item_price            18
# dtype: int64

# %%
https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv

# %%
crime = pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv")

# %%
crime
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 0   1960   179323175   3384200   288460   3095700    9110          17190
# 1   1961   182992000   3488000   289390   3198600    8740          17220
# 2   1962   185771000   3752200   301510   3450700    8530          17550
# 3   1963   188483000   4109500   316970   3792500    8640          17650
# 4   1964   191141000   4564600   364220   4200400    9360          21420
# 5   1965   193526000   4739400   387390   4352000    9960          23410
# 6   1966   195576000   5223500   430180   4793300   11040          25820
# 7   1967   197457000   5903400   499930   5403500   12240          27620
# 8   1968   199399000   6720200   595010   6125200   13800          31670
# 9   1969   201385000   7410900   661870   6749000   14760          37170
# 10  1970   203235298   8098000   738820   7359200   16000          37990
# 11  1971   206212000   8588200   816500   7771700   17780          42260
# ...

# %%
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                55 non-null     int64
#  1   Population          55 non-null     int64
#  2   Total               55 non-null     int64
#  3   Violent             55 non-null     int64
#  4   Property            55 non-null     int64
#  5   Murder              55 non-null     int64
#  6   Forcible_Rape       55 non-null     int64
#  7   Robbery             55 non-null     int64
#  8   Aggravated_assault  55 non-null     int64
#  9   Burglary            55 non-null     int64
#  10  Larceny_Theft       55 non-null     int64
#  11  Vehicle_Theft       55 non-null     int64
# dtypes: int64(12)
# memory usage: 5.3 KB

# %%
#Convert the type of the column Year to datetime64
crime.Year = pd.to_datetime(crime.Year, format='%Y')

# %%
crime.head()
# Out:
#         Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0 1960-01-01   179323175  3384200   288460   3095700    9110          17190
# 1 1961-01-01   182992000  3488000   289390   3198600    8740          17220
# 2 1962-01-01   185771000  3752200   301510   3450700    8530          17550
# 3 1963-01-01   188483000  4109500   316970   3792500    8640          17650
# 4 1964-01-01   191141000  4564600   364220   4200400    9360          21420
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800
# 3   116470              174210   1086400        2297800         408300
# 4   130390              203050   1213200        2514400         472800

# %%
#Set the Year column as the index of the dataframe

# %%
crime = crime.set_index('Year', drop = True)
crime.head()
# Out:
#             Population    Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01   179323175  3384200   288460   3095700    9110          17190
# 1961-01-01   182992000  3488000   289390   3198600    8740          17220
# 1962-01-01   185771000  3752200   301510   3450700    8530          17550
# 1963-01-01   188483000  4109500   316970   3792500    8640          17650
# 1964-01-01   191141000  4564600   364220   4200400    9360          21420
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01   107840              154320    912100        1855400
# 1961-01-01   106670              156760    949600        1913000
# 1962-01-01   110860              164570    994300        2089600
# 1963-01-01   116470              174210   1086400        2297800
# 1964-01-01   130390              203050   1213200        2514400
#
#             Vehicle_Theft
# Year
# 1960-01-01         328200
# 1961-01-01         336000
# ...

# %%
#Delete the Total column

# %%
# select just Robbery and Murder column

# %%
# select only those rows of df where murder is greater than 24000
crime[crime['Murder']>24000]
# Out:
#             Population     Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1991-01-01   252177000  14872900  1911770  12961100   24700         106590
# 1993-01-01   257908000  14144800  1926020  12218800   24530         106010
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1991-01-01   687730             1092740   3157200        8142200
# 1993-01-01   659870             1135610   2834800        7820900
#
#             Vehicle_Theft
# Year
# 1991-01-01        1661700
# 1993-01-01        1563100

# %%
#calculate the mean murder for each different year
crime.groupby('Year')['Murder'].mean()
# Out:
# Year
# 1960-01-01     9110
# 1961-01-01     8740
# 1962-01-01     8530
# 1963-01-01     8640
# 1964-01-01     9360
# 1965-01-01     9960
# 1966-01-01    11040
# 1967-01-01    12240
# 1968-01-01    13800
# 1969-01-01    14760
# 1970-01-01    16000
# 1971-01-01    17780
# 1972-01-01    18670
# 1973-01-01    19640
# 1974-01-01    20710
# 1975-01-01    20510
# 1976-01-01    18780
# 1977-01-01    19120
# 1978-01-01    19560
# 1979-01-01    21460
# 1980-01-01    23040
# 1981-01-01    22520
# 1982-01-01    21010
# 1983-01-01    19310
# 1984-01-01    18690
# 1985-01-01    18980
# 1986-01-01    20613
# 1987-01-01    20096
# 1988-01-01    20680
# 1989-01-01    21500
# 1990-01-01    23440
# 1991-01-01    24700
# 1992-01-01    23760
# 1993-01-01    24530
# 1994-01-01    23330
# 1995-01-01    21610
# 1996-01-01    19650
# 1997-01-01    18208
# 1998-01-01    16914
# 1999-01-01    15522
# 2000-01-01    15586
# 2001-01-01    16037
# 2002-01-01    16229
# 2003-01-01    16528
# 2004-01-01    16148
# ...

# %%
# sort df by values in murder in desc order and voilent in asc order

# %%
crime.sort_values(by = ['Murder','Violent'], ascending=[False, True])
# Out:
#             Population     Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1991-01-01   252177000  14872900  1911770  12961100   24700         106590
# 1993-01-01   257908000  14144800  1926020  12218800   24530         106010
# 1992-01-01   255082000  14438200  1932270  12505900   23760         109060
# 1990-01-01   248709873  14475600  1820130  12655500   23440         102560
# 1994-01-01   260341000  13989500  1857670  12131900   23330         102220
# 1980-01-01   225349264  13408300  1344520  12063700   23040          82990
# 1981-01-01   229146000  13423800  1361820  12061900   22520          82500
# 1995-01-01   262755000  13862700  1798790  12063900   21610          97470
# 1989-01-01   248239000  14251400  1646040  12605400   21500          94500
# 1979-01-01   220099000  12249500  1208030  11041500   21460          76390
# 1982-01-01   231534000  12974400  1322390  11652000   21010          78770
# ...

# %%
df = pd.read_csv('https://raw.githubusercontent.com/kjam/data-wrangling-pycon/master/data/berlin_weather_oldest.csv')

# %%
df
# Out:
#                   STATION         STATION_NAME      DATE  PRCP  SNWD  SNOW  \
# 0       GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999
# 1       GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999
# 2       GHCND:GME00111445  BERLIN TEMPELHOF GM  19310103 -9999 -9999 -9999
# 3       GHCND:GME00111445  BERLIN TEMPELHOF GM  19310105    13 -9999 -9999
# 4       GHCND:GME00111445  BERLIN TEMPELHOF GM  19310106 -9999 -9999 -9999
# ...                   ...                  ...       ...   ...   ...   ...
# 117203  GHCND:GMM00010385        SCHONEFELD GM  19921227     0 -9999 -9999
# 117204  GHCND:GMM00010385        SCHONEFELD GM  19921228     0 -9999 -9999
# 117205  GHCND:GMM00010385        SCHONEFELD GM  19921229     0 -9999 -9999
# 117206  GHCND:GMM00010385        SCHONEFELD GM  19921230     0 -9999 -9999
# 117207  GHCND:GMM00010385        SCHONEFELD GM  19921231     3 -9999 -9999
#
# ...

# %%
#Change the column name from any of the above file.

# %%
#Arrange  column values in ascending order.

# %%
#Get the subset rows 11, 24, 37
